# %% [markdown]
# # Purity Reviewer Example

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from PurityReviewer.Reviewers.MatchedPurityReviewer import MatchedPurityReviewer
from PurityReviewer.Reviewers.ManualPurityReviewer import ManualPurityReviewer
from PurityReviewer.AppComponents.utils import download_rdata
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # Run with simuated tumor data
# ## Setup
#
# Clone the `SimulatedTumorData` repo and install in your environment.
# ```
# cd <path to put SimulatedTumorData repo>
# git clone https://github.com/getzlab/SimulatedTumorData
#
# conda activate <your env>
# pip install -e <path to put SimulatedTumorData repo>
# ```
#
# This only needs to be done once.

# %% [markdown]
# ## Load simulated data

# %%
# from SimulatedTumorData.src.generate_simulated_data import load_patients_and_samples

# %%
# samples, participants = load_patients_and_samples(path_to_sim_data="SimulatedTumorData/sim_data")

# %% [markdown]
# ## Pass in data

# %%
from PurityReviewer.AppComponents.utils import parse_absolute_soln, CSIZE_DEFAULT
# from PurityReviewer.AppComponents.utils import parse_absolute_soln_simulatedTumorData

# %%
# data_path = 'simulated_data_purity_review'

# %%
# matched_reviewer = MatchedPurityReviewer()
# matched_reviewer.set_review_data(
#     data_path=data_path, 
#     description='Matched purity reviewer for simulated data', 
#     df=samples,
#     index=samples.index, 
# )
# matched_reviewer.set_review_app(
#     sample_info_cols=['ABSOLUTE_plot_fn', 'wxs_purity', 'wxs_ploidy'],
#     acs_col='cnv_seg_fn', 
#     maf_col='maf_fn',
#     rdata_fn_col='ABSOLUTE_RData',
#     mut_fig_hover_data=['Hugo_Symbol', 'Chromosome', 'Start_position'],
#     csize=CSIZE_DEFAULT,
#     custom_parse_absolute_soln=parse_absolute_soln_simulatedTumorData # <-- update with my_custom_parse_absolute_soln()
# )

# matched_reviewer.set_default_review_data_annotations_configuration()
# matched_reviewer.set_default_autofill()

# %% [markdown]
# ## Run the reviewer

# %%
# matched_reviewer.run(port=8099, mode='tab', collapsable=False, hide_history_df_cols=['source_data_fn'])

# %%
# matched_reviewer.get_annot()

# %% [markdown]
# # Purity Review from CGA characterization pipeline Terra workspace

# %% [markdown]
# ## Load data

# %%
import dalmatian

# %% [markdown]
# ```
# import os
# os.environ["GCLOUD_PROJECT"] = <google project>
#
# wm = dalmatian.WorkspaceManager(<namespace>/<workspace_name>)
# pairs_df = wm.get_pairs()
#
# # Download rdata from ABSOLUTE locally
# rdata_dir = <directory to save rData>
# downloaded_rdata_s = download_rdata(pairs_df['absolute_rdata'], rdata_dir=rdata_dir)
# downloaded_rdata_s.name = 'local_absolute_rdata'
# pairs_df = pd.concat([pairs_df, downloaded_rdata_s], axis=1)
# ```

# %%
workspace = 'broad-tcga-wgs-terra/TCGA_BRCA_WGS'
wm = dalmatian.WorkspaceManager(workspace)
wm_pairs_df = wm.get_pairs()
wm_pairs_df = wm_pairs_df[wm_pairs_df['absolute_rdata_WGS'].notna()].set_index('tumor_submitter_id')
display(wm_pairs_df)
# Out:
#                                              participant tumor_type_code  \
# tumor_submitter_id
# TCGA-D8-A27T-01A    27c1c094-690b-4973-8900-a797ad88f98c              TP
# TCGA-C8-A26W-01A    ff0f875f-113a-4c0f-8c0a-4259cd496e6d              TP
01A    gs://fc-secure-df24feb9-b120-454d-98f1-2ac4880...  ...
# TCGA-C8-A12L-01A    gs://fc-secure-df24feb9-b120-454d-98f1-2ac4880...  ...
# TCGA-AR-A0TQ-01A    gs://fc-secure-df24feb9-b120-454d-98f1-2ac4880...  ...
# TCGA-A8-A0A7-01A    gs://fc-secure-df24feb9-b120-454d-98f1-2ac4880...  ...
#
#                    T_mismatch_rate_WGS  \
# tumor_submitter_id
# TCGA-D8-A27T-01A                   NaN
# TCGA-C8-A26W-01A              0.004736
# TCGA-D8-A1JA-01A              0.004527
# TCGA-BH-A0B7-01A                   NaN
# TCGA-C8-A12M-01A                   NaN
# TCGA-A8-A08J-01A                   NaN
# TCGA-D8-A27N-01A              0.005474
# TCGA-E2-A14P-01A                   NaN
# TCGA-C8-A132-01A                   NaN
# TCGA-D8-A140-01A                   NaN
# TCGA-A8-A07B-01A                   NaN
# TCGA-A2-A0T3-01A                   NaN
# TCGA-A8-A09I-01A                   NaN
# TCGA-EW-A1OZ-01A                   NaN
# TCGA-AN-A049-01A              0.004004
# TCGA-AO-A12D-01A                   NaN
# TCGA-EW-A1IW-01A                   NaN
# TCGA-EW-A1PH-01A                   NaN
# TCGA-C8-A12L-01A                   NaN
# TCGA-AR-A0TQ-01A                   NaN
# TCGA-A8-A0A7-01A                   NaN
#
#                                              recapseg_tn_coverage_WGS  \
# tumor_submitter_id
# TCGA-D8-A27T-01A                                                  NaN
# TCGA-C8-A26W-01A    gs://fc-secure-df24feb9-b120-454d-98f1-2ac4880...
# TCGA-D8-A1JA-01A    gs://fc-secure-df24feb9-b120-454d-98f1-2ac4880...
# TCGA-BH-A0B7-01A                                                  NaN
# TCGA-C8-A12M-01A                                                  NaN
# TCGA-A8-A08J-01A                                                  NaN
# TCGA-D8-A27N-01A    gs://fc-secure-df24feb9-b120-454d-98f1-2ac4880...
# TCGA-E2-A14P-01A                                                  NaN
# TCGA-C8-A132-01A                                                  NaN
# TCGA-D8-A140-01A                                                  NaN
# TCGA-A8-A07B-01A                                                  NaN
# TCGA-A2-A0T3-01A                                                  NaN
# TCGA-A8-A09I-01A                                                  NaN
# TCGA-EW-A1OZ-01A                                                  NaN
# TCGA-AN-A049-01A                                                  NaN
# TCGA-AO-A12D-01A                                                  NaN
# TCGA-EW-A1IW-01A                                                  NaN
# TCGA-EW-A1PH-01A                                                  NaN
# TCGA-C8-A12L-01A                                                  NaN
# TCGA-AR-A0TQ-01A                                                  NaN
# TCGA-A8-A0A7-01A                                                  NaN
#
#                    CrossCheck_min_LOD_value N_mean_coverage_WGS  \
# tumor_submitter_id
# TCGA-D8-A27T-01A                        NaN                 NaN
# TCGA-C8-A26W-01A                  70.145458           39.437779
# TCGA-D8-A1JA-01A                  82.564876           35.604842
# TCGA-BH-A0B7-01A                        NaN                 NaN
# TCGA-C8-A12M-01A                        NaN                 NaN
# TCGA-A8-A08J-01A                        NaN                 NaN
# TCGA-D8-A27N-01A                  90.823794           34.502734
# TCGA-E2-A14P-01A                        NaN                 NaN
# TCGA-C8-A132-01A                        NaN                 NaN
# TCGA-D8-A140-01A                        NaN                 NaN
# TCGA-A8-A07B-01A                        NaN                 NaN
# TCGA-A2-A0T3-01A                        NaN                 NaN
# TCGA-A8-A09I-01A                        NaN                 NaN
# TCGA-EW-A1OZ-01A                        NaN                 NaN
# TCGA-AN-A049-01A                  78.392618           29.346867
# TCGA-AO-A12D-01A                        NaN                 NaN
# TCGA-EW-A1IW-01A                        NaN                 NaN
# TCGA-EW-A1PH-01A                        NaN                 NaN
# TCGA-C8-A12L-01A                        NaN                 NaN
# TCGA-AR-A0TQ-01A                        NaN                 NaN
# TCGA-A8-A0A7-01A                        NaN                 NaN
#
#                    T_median_insert_size_WGS N_pct_chimeras_WGS  \
# tumor_submitter_id
# TCGA-D8-A27T-01A                        NaN                NaN
# TCGA-C8-A26W-01A                        406           0.034528
# TCGA-D8-A1JA-01A                        387           0.042127
# TCGA-BH-A0B7-01A                        NaN                NaN
# TCGA-C8-A12M-01A                        NaN                NaN
# TCGA-A8-A08J-01A                        NaN                NaN
# TCGA-D8-A27N-01A                        406           0.037964
# TCGA-E2-A14P-01A                        NaN                NaN
# TCGA-C8-A132-01A                        NaN                NaN
# TCGA-D8-A140-01A                        NaN                NaN
# TCGA-A8-A07B-01A                        NaN                NaN
# TCGA-A2-A0T3-01A                        NaN                NaN
# TCGA-A8-A09I-01A                        NaN                NaN
# TCGA-EW-A1OZ-01A                        NaN                NaN
# TCGA-AN-A049-01A                        461           0.032675
# TCGA-AO-A12D-01A                        NaN                NaN
# TCGA-EW-A1IW-01A                        NaN                NaN
# TCGA-EW-A1PH-01A                        NaN                NaN
# TCGA-C8-A12L-01A                        NaN                NaN
# TCGA-AR-A0TQ-01A                        NaN                NaN
# TCGA-A8-A0A7-01A                        NaN                NaN
#
#                                              CrossCheck_min_LOD_lanes  \
# tumor_submitter_id
# TCGA-D8-A27T-01A                                                  NaN
# TCGA-C8-A26W-01A    TCGA-C8-A26W-01A-11D-A89A-36.WholeGenome.RP-16...
# TCGA-D8-A1JA-01A    TCGA-D8-A1JA-01A-11D-A897-36.WholeGenome.RP-16...
# TCGA-BH-A0B7-01A                                                  NaN
# TCGA-C8-A12M-01A                                                  NaN
# TCGA-A8-A08J-01A                                                  NaN
# TCGA-D8-A27N-01A    TCGA-D8-A27N-01A-11D-A89A-36.WholeGenome.RP-16...
# TCGA-E2-A14P-01A                                                  NaN
# TCGA-C8-A132-01A                                                  NaN
# TCGA-D8-A140-01A                                                  NaN
# TCGA-A8-A07B-01A                                                  NaN
# TCGA-A2-A0T3-01A                                                  NaN
# TCGA-A8-A09I-01A                                                  NaN
# TCGA-EW-A1OZ-01A                                                  NaN
# TCGA-AN-A049-01A    TCGA-AN-A049-01A-21D-A89H-36.WholeGenome.RP-16...
# TCGA-AO-A12D-01A                                                  NaN
# TCGA-EW-A1IW-01A                                                  NaN
# TCGA-EW-A1PH-01A                                                  NaN
# TCGA-C8-A12L-01A                                                  NaN
# TCGA-AR-A0TQ-01A                                                  NaN
# TCGA-A8-A0A7-01A                                                  NaN
#
#                    T_mean_coverage_WGS alleliccapseg_skew_WGS  \
# tumor_submitter_id
# TCGA-D8-A27T-01A                   NaN                    NaN
# TCGA-C8-A26W-01A             71.227847                0.99848
# TCGA-D8-A1JA-01A             88.668252              0.9990065
# TCGA-BH-A0B7-01A                   NaN                    NaN
# TCGA-C8-A12M-01A                   NaN                    NaN
# TCGA-A8-A08J-01A                   NaN                    NaN
# TCGA-D8-A27N-01A             74.300717              0.9984943
# TCGA-E2-A14P-01A                   NaN                    NaN
# TCGA-C8-A132-01A                   NaN                    NaN
# TCGA-D8-A140-01A                   NaN                    NaN
# TCGA-A8-A07B-01A                   NaN                    NaN
# TCGA-A2-A0T3-01A                   NaN                    NaN
# TCGA-A8-A09I-01A                   NaN                    NaN
# TCGA-EW-A1OZ-01A                   NaN                    NaN
# TCGA-AN-A049-01A              88.95042                    NaN
# TCGA-AO-A12D-01A                   NaN                    NaN
# TCGA-EW-A1IW-01A                   NaN                    NaN
# TCGA-EW-A1PH-01A                   NaN                    NaN
# TCGA-C8-A12L-01A                   NaN                    NaN
# TCGA-AR-A0TQ-01A                   NaN                    NaN
# TCGA-A8-A0A7-01A                   NaN                    NaN
#
#                    N_mean_read_length_WGS
# tumor_submitter_id
# TCGA-D8-A27T-01A                      NaN
# TCGA-C8-A26W-01A                      151
# TCGA-D8-A1JA-01A                      151
# TCGA-BH-A0B7-01A                      NaN
# TCGA-C8-A12M-01A                      NaN
# TCGA-A8-A08J-01A                      NaN
# TCGA-D8-A27N-01A                      151
# TCGA-E2-A14P-01A                      NaN
# TCGA-C8-A132-01A                      NaN
# TCGA-D8-A140-01A                      NaN
# TCGA-A8-A07B-01A                      NaN
# TCGA-A2-A0T3-01A                      NaN
# TCGA-A8-A09I-01A                      NaN
# TCGA-EW-A1OZ-01A                      NaN
# TCGA-AN-A049-01A                      151
# TCGA-AO-A12D-01A                      NaN
# TCGA-EW-A1IW-01A                      NaN
# TCGA-EW-A1PH-01A                      NaN
# TCGA-C8-A12L-01A                      NaN
# TCGA-AR-A0TQ-01A                      NaN
# TCGA-A8-A0A7-01A                      NaN
#
# [21 rows x 151 columns]

# %%
# download rdata locally
local_rdata_dir = 'local_rdata'
wm_pairs_df['local_absolute_rdata'] = download_rdata(wm_pairs_df['absolute_rdata_WGS'], rdata_dir=local_rdata_dir)
# Out:
# /var/folders/y8/cnhv8ly14tz5kjxx2jd_06rc0000gp/T/ipykernel_53851/2186493005.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   wm_pairs_df['local_absolute_rdata'] = download_rdata(wm_pairs_df['absolute_rdata_WGS'], rdata_dir=local_rdata_dir)

# %%
wm_pairs_df['local_absolute_rdata'].iloc[0]
# Out:
# 'local_rdata/TCGA-D8-A27T-01A.absolute.rdata'

# %% [markdown]
# ## Pass in data

# %%
from PurityReviewer.AppComponents.utils import CSIZE_DEFAULT
sex_chr_map = {'23': 'X', '24': 'Y'}
rename_chroms = {x: sex_chr_map[x] if x in sex_chr_map.keys() else x for x in CSIZE_DEFAULT.keys()}
custom_csize = {f'chr{rename_chroms[chrom]}': length for chrom, length in CSIZE_DEFAULT.items()}
custom_csize
# Out:
# {'chr1': 249250621,
#  'chr2': 243199373,
#  'chr3': 198022430,
#  'chr4': 191154276,
#  'chr5': 180915260,
#  'chr6': 171115067,
#  'chr7': 159138663,
#  'chr8': 146364022,
#  'chr9': 141213431,
#  'chr10': 135534747,
#  'chr11': 135006516,
#  'chr12': 133851895,
#  'chr13': 115169878,
#  'chr14': 107349540,
#  'chr15': 102531392,
#  'chr16': 90354753,
#  'chr17': 81195210,
#  'chr18': 78077248,
#  'chr19': 59128983,
#  'chr20': 63025520,
#  'chr21': 48129895,
#  'chr22': 51304566,
#  'chrX': 156040895,
#  'chrY': 57227415}

# %%
from rpy2.robjects import r, pandas2ri
import rpy2.robjects as robjects

def my_custom_parse_absolute_soln(rdata_path: str): # has to be a local path   
    absolute_rdata_cols = ['alpha', 'tau', 'tau_hat', '0_line', '1_line',
                       'sigma_H', 
                       'theta_Q', 
                       'lambda',  
                       'SCNA_likelihood', 
                       'Kar_likelihood', 
                       'SSNVs_likelihood']
    pandas2ri.activate()
    print('New version!')
    r_list_vector = robjects.r['load'](rdata_path)
    r_list_vector = robjects.r[r_list_vector[0]]
    # r_data_id = r_list_vector.names[0]
    # rdata_tables = r_list_vector.rx2(str(r_data_id))
    
    # mode_res = rdata_tables.rx2('mode.res')
    # mode_tab = mode_res.rx2('mode.tab')
    mode_res = r_list_vector.rx2('mode.res')
    mode_tab = r_list_vector.rx2('mode.tab') # or segtab?
    mod_tab_df = pd.DataFrame(columns=absolute_rdata_cols)
    mod_tab_df['alpha'] = mode_tab[:, 0]
    mod_tab_df['tau'] = mode_tab[:, 1]
    mod_tab_df['tau_hat'] = mode_tab[:, 7]
    mod_tab_df['0_line'] = mode_tab[:, 3]
    mod_tab_df['step_size'] = mode_tab[:, 4] * 2
    mod_tab_df['1_line'] = mod_tab_df['step_size'] + mod_tab_df['0_line']
    mod_tab_df['sigma_H'] = mode_tab[:, 8]
    mod_tab_df['theta_Q'] = mode_tab[:, 11]
    mod_tab_df['lambda'] = mode_tab[:, 12]
    mod_tab_df['SCNA_likelihood'] = mode_tab[:, 15]
    mod_tab_df['Kar_likelihood'] = mode_tab[:, 17]
    mod_tab_df['SSNVs_likelihood'] = mode_tab[:, 20]

    return mod_tab_df

# %%
matched_reviewer = MatchedPurityReviewer()
matched_reviewer.set_review_data(
    data_path = 'matched_purity_reviwer_output', 
    description= 'BRCA purity review', 
    df=wm_pairs_df,
    index=wm_pairs_df.index,
)

matched_reviewer.set_review_app(
    sample_info_cols=['absolute_highres_plot_WGS', 'hapaseg_allelic_segmentation_plot_WGS'],
    acs_col='hapaseg_segfile_WGS', 
    maf_col='absolute_downsample_MAF_WGS',
    rdata_fn_col='local_absolute_rdata',
    mut_fig_hover_data=['Hugo_Symbol', 'Chromosome', 'Start_position'],
    csize=CSIZE_DEFAULT,
    # custom_parse_absolute_soln=my_custom_parse_absolute_soln
)

matched_reviewer.set_default_review_data_annotations_configuration()
matched_reviewer.set_default_autofill()

# %% [markdown]
# ## Run the reviewer

# %%
matched_reviewer.run(port=8012, mode='tab')
# Out:
# Setting auto_export_path to matched_purity_reviwer_output/data.auto_export
# Making directory matched_purity_reviwer_output/data.auto_export for auto exporting.
# Using matched_purity_reviwer_output/data.auto_export for auto exporting.
# Dash app running on http://0.0.0.0:8099/
# /Users/odias/PurityReviewer/precalled_purity_venv/lib/python3.9/site-packages/AnnoMate/ReviewDataApp.py:738: UserWarning:
#
# You are in test mode. Your data will not be saved.
